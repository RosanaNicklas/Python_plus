# %%
pip install Ggplot
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from plotnine import *

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
(ggplot(df, aes("PetalLengthCm", "PetalWidthCm", color = "Species")) +
  geom_point())
# Out:
# <ggplot: (312177622)>

# %%
(ggplot(df, aes("SepalLengthCm","SepalWidthCm", color = "Species")) +
  geom_point())
# Out:
# <ggplot: (312298897)>

# %%
(ggplot(df, aes("PetalLengthCm", "PetalWidthCm", color = "Species")) +
  geom_boxplot() )
# Out:
# <ggplot: (312673250)>

# %%
(ggplot(df, aes("SepalLengthCm","SepalWidthCm", color = "Species")) +
  geom_boxplot())
# Out:
# <ggplot: (312435369)>
